# %% [markdown]
# ![image.png](attachment:image.png)

# %%
exp = int(input("nhap so kinh nghiem: "))
grade = input("nhap xep loai: ") 
print(exp)
print(grade)
# Out:
# nhap so kinh nghiem: 3
# nhap xep loai: M
# 3
# M
